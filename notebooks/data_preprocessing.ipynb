# %%
import pandas as pd
import re

# Load your DataFrame
df = pd.read_csv(r'C:\Users\Admin.DESKTOP-M4R2VLU\ourweek5\telegram_data.csv')

# %%
df
# Out:
#        Channel Title Channel Username     ID  \
# 0     Dubai in Addis   @dubaiinaddis1  31395
# 1     Dubai in Addis   @dubaiinaddis1  31394
# 2     Dubai in Addis   @dubaiinaddis1  31393
# 3     Dubai in Addis   @dubaiinaddis1  31392
# 4     Dubai in Addis   @dubaiinaddis1  31391
# ...              ...              ...    ...
# 3438  Dubai in Addis   @dubaiinaddis1  26470
# 3439  Dubai in Addis   @dubaiinaddis1  26469
# 3440  Dubai in Addis   @dubaiinaddis1  26468
# 3441  Dubai in Addis   @dubaiinaddis1  26467
# 3442  Dubai in Addis   @dubaiinaddis1  26466
#
#                                                 Message  \
# 0                                                   NaN
# 1     የ 1 አመት ሳይዝ \n\n1500 ብር \n\n0913870090\n\nለማዘዝ...
# 2                                                   NaN
# 3     ዘናጭ 2 ፒስ\n\nከ3-6 እና ከ 6-9  ወር \n\n\n1500 ብር\n\...
# 4                                                   NaN
# ...                                                 ...
# 3438    5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# 3439                                                NaN
# 3440                                                NaN
# 3441                                                NaN
# 3442                                                NaN
#
#                            Date                       Media Path
# 0     2024-09-27 14:52:24+00:00  photos\@dubaiinaddis1_31395.jpg
# 1     2024-09-27 14:52:24+00:00  photos\@dubaiinaddis1_31394.jpg
# 2     2024-09-27 14:46:21+00:00  photos\@dubaiinaddis1_31393.jpg
# 3     2024-09-27 14:46:21+00:00  photos\@dubaiinaddis1_31392.jpg
# 4     2024-09-27 14:38:32+00:00  photos\@dubaiinaddis1_31391.jpg
# ...                         ...                              ...
# 3438  2024-02-13 13:40:20+00:00  photos\@dubaiinaddis1_26470.jpg
# 3439  2024-02-13 13:40:20+00:00  photos\@dubaiinaddis1_26469.jpg
# 3440  2024-02-13 13:40:20+00:00  photos\@dubaiinaddis1_26468.jpg
# 3441  2024-02-13 13:40:20+00:00  photos\@dubaiinaddis1_26467.jpg
# 3442  2024-02-13 13:40:19+00:00  photos\@dubaiinaddis1_26466.jpg
#
# [3443 rows x 6 columns]

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = df['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 1924

# %%
df = df.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (1519, 6)

# %%
df
# Out:
#        Channel Title Channel Username     ID  \
# 1     Dubai in Addis   @dubaiinaddis1  31394
# 3     Dubai in Addis   @dubaiinaddis1  31392
# 5     Dubai in Addis   @dubaiinaddis1  31390
# 7     Dubai in Addis   @dubaiinaddis1  31388
# 8     Dubai in Addis   @dubaiinaddis1  31387
# ...              ...              ...    ...
# 3418  Dubai in Addis   @dubaiinaddis1  26501
# 3426  Dubai in Addis   @dubaiinaddis1  26482
# 3432  Dubai in Addis   @dubaiinaddis1  26476
# 3437  Dubai in Addis   @dubaiinaddis1  26471
# 3438  Dubai in Addis   @dubaiinaddis1  26470
#
#                                                 Message  \
# 1     የ 1 አመት ሳይዝ \n\n1500 ብር \n\n0913870090\n\nለማዘዝ...
# 3     ዘናጭ 2 ፒስ\n\nከ3-6 እና ከ 6-9  ወር \n\n\n1500 ብር\n\...
# 5     ዘናጭ 2 ፒስ\n\nከ9 ወር- 3 አመት ሳይዝ አለዉ\n\nለልደትም ሆነ ለ...
# 7     3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nሱ...
# 8     3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nእ...
# ...                                                 ...
# 3418  5 ፍሬ እጅጌ ሙሉ የዳይፐር ቲሸርት\nከ0-3 ወር \n2000 ብር\n091...
# 3426    5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# 3432    5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# 3437    5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# 3438    5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
#
#                            Date                       Media Path
# 1     2024-09-27 14:52:24+00:00  photos\@dubaiinaddis1_31394.jpg
# 3     2024-09-27 14:46:21+00:00  photos\@dubaiinaddis1_31392.jpg
# 5     2024-09-27 14:38:32+00:00  photos\@dubaiinaddis1_31390.jpg
# 7     2024-09-27 14:32:01+00:00  photos\@dubaiinaddis1_31388.jpg
# 8     2024-09-27 14:29:47+00:00  photos\@dubaiinaddis1_31387.jpg
# ...                         ...                              ...
# 3418  2024-02-14 10:12:13+00:00  photos\@dubaiinaddis1_26501.jpg
# 3426  2024-02-13 14:05:49+00:00  photos\@dubaiinaddis1_26482.jpg
# 3432  2024-02-13 14:03:36+00:00  photos\@dubaiinaddis1_26476.jpg
# 3437  2024-02-13 13:40:27+00:00  photos\@dubaiinaddis1_26471.jpg
# 3438  2024-02-13 13:40:20+00:00  photos\@dubaiinaddis1_26470.jpg
#
# [1519 rows x 6 columns]

# %%
message_df=df['Message']
message_df
# Out:
# 1       የ 1 አመት ሳይዝ \n\n1500 ብር \n\n0913870090\n\nለማዘዝ...
# 3       ዘናጭ 2 ፒስ\n\nከ3-6 እና ከ 6-9  ወር \n\n\n1500 ብር\n\...
# 5       ዘናጭ 2 ፒስ\n\nከ9 ወር- 3 አመት ሳይዝ አለዉ\n\nለልደትም ሆነ ለ...
# 7       3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nሱ...
# 8       3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nእ...
#                               ...
# 3418    5 ፍሬ እጅጌ ሙሉ የዳይፐር ቲሸርት\nከ0-3 ወር \n2000 ብር\n091...
# 3426      5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# 3432      5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# 3437      5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# 3438      5 ፍሬ ቢብስ( የለሀጭ)\n600 ብር \n0913870090\n\n@KiDu_W
# Name: Message, Length: 1519, dtype: object

# %%
# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df['Message'] = df['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(df.head())
# Out:
#     Channel Title Channel Username     ID  \
# 1  Dubai in Addis   @dubaiinaddis1  31394
# 3  Dubai in Addis   @dubaiinaddis1  31392
# 5  Dubai in Addis   @dubaiinaddis1  31390
# 7  Dubai in Addis   @dubaiinaddis1  31388
# 8  Dubai in Addis   @dubaiinaddis1  31387
#
#                                              Message  \
# 1  የ 1 አመት ሳይዝ \n\n1500 ብር \n\n0913870090\n\nለማዘዝ...
# 3  ዘናጭ 2 ፒስ\n\nከ3-6 እና ከ 6-9  ወር \n\n\n1500 ብር\n\...
# 5  ዘናጭ 2 ፒስ\n\nከ9 ወር- 3 አመት ሳይዝ አለዉ\n\nለልደትም ሆነ ለ...
# 7  3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nሱ...
# 8  3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nእ...
#
#                         Date                       Media Path
# 1  2024-09-27 14:52:24+00:00  photos\@dubaiinaddis1_31394.jpg
# 3  2024-09-27 14:46:21+00:00  photos\@dubaiinaddis1_31392.jpg
# 5  2024-09-27 14:38:32+00:00  photos\@dubaiinaddis1_31390.jpg
# 7  2024-09-27 14:32:01+00:00  photos\@dubaiinaddis1_31388.jpg
# 8  2024-09-27 14:29:47+00:00  photos\@dubaiinaddis1_31387.jpg
# C:\Users\Admin.DESKTOP-M4R2VLU\AppData\Local\Temp\ipykernel_3308\3905982540.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Message'] = df['Message'].apply(remove_emojis)

# %%
df.to_csv('clean_data.csv')

# %%
import re

def label_message_utf8_with_birr(message):
    # Split the message at the first occurrence of '\n'
    if '\n' in message:
        first_line, remaining_message = message.split('\n', 1)
    else:
        first_line, remaining_message = message, ""
    
    labeled_tokens = []
    
    # Tokenize the first line
    first_line_tokens = re.findall(r'\S+', first_line)
    
    # Label the first token as B-PRODUCT and the rest as I-PRODUCT
    if first_line_tokens:
        labeled_tokens.append(f"{first_line_tokens[0]} B-PRODUCT")  # First token as B-PRODUCT
        for token in first_line_tokens[1:]:
            labeled_tokens.append(f"{token} I-PRODUCT")  # Remaining tokens as I-PRODUCT
    
    # Process the remaining message normally
    if remaining_message:
        lines = remaining_message.split('\n')
        for line in lines:
            tokens = re.findall(r'\S+', line)  # Tokenize each line while considering non-ASCII characters
            
            for token in tokens:
                # Check if token is a price (e.g., 500 ETB, $100, or ብር)
                if re.match(r'^\d{10,}$', token):
                    labeled_tokens.append(f"{token} O")  # Label as O for "other" or outside of any entity
                elif re.match(r'^\d+(\.\d{1,2})?$', token) or 'ETB' in token or 'ዋጋ' in token or '$' in token or 'ብር' in token:
                    labeled_tokens.append(f"{token} I-PRICE")
                # Check if token could be a contact (e.g., cities or general contact Number)
                elif any(contact in token for contact in ['09', '0913870090']):
                    labeled_tokens.append(f"{token} I-CONTACT")
                # Assume other tokens are part of a product name or general text
                else:
                    labeled_tokens.append(f"{token} O")
    
    return "\n".join(labeled_tokens)

# Apply the updated function to the non-null messages
df['Labeled_Message'] = df['Message'].apply(label_message_utf8_with_birr)

# Display the updated DataFrame
df.head()
# Out:
# C:\Users\Admin.DESKTOP-M4R2VLU\AppData\Local\Temp\ipykernel_3308\3826184194.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Labeled_Message'] = df['Message'].apply(label_message_utf8_with_birr)
#     Channel Title Channel Username     ID  \
# 1  Dubai in Addis   @dubaiinaddis1  31394
# 3  Dubai in Addis   @dubaiinaddis1  31392
# 5  Dubai in Addis   @dubaiinaddis1  31390
# 7  Dubai in Addis   @dubaiinaddis1  31388
# 8  Dubai in Addis   @dubaiinaddis1  31387
#
#                                              Message  \
# 1  የ 1 አመት ሳይዝ \n\n1500 ብር \n\n0913870090\n\nለማዘዝ...
# 3  ዘናጭ 2 ፒስ\n\nከ3-6 እና ከ 6-9  ወር \n\n\n1500 ብር\n\...
# 5  ዘናጭ 2 ፒስ\n\nከ9 ወር- 3 አመት ሳይዝ አለዉ\n\nለልደትም ሆነ ለ...
# 7  3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nሱ...
# 8  3 ፒስ 100%  ኮተን የአራስ ልብስ\n\nኮፍያ \nየዳይፐር ቲሸርት\nእ...
#
#                         Date                       Media Path  \
# 1  2024-09-27 14:52:24+00:00  photos\@dubaiinaddis1_31394.jpg
# 3  2024-09-27 14:46:21+00:00  photos\@dubaiinaddis1_31392.jpg
# 5  2024-09-27 14:38:32+00:00  photos\@dubaiinaddis1_31390.jpg
# 7  2024-09-27 14:32:01+00:00  photos\@dubaiinaddis1_31388.jpg
# 8  2024-09-27 14:29:47+00:00  photos\@dubaiinaddis1_31387.jpg
#
#                                      Labeled_Message
# 1  የ B-PRODUCT\n1 I-PRODUCT\nአመት I-PRODUCT\nሳይዝ I...
# 3  ዘናጭ B-PRODUCT\n2 I-PRODUCT\nፒስ I-PRODUCT\nከ3-6...
# 5  ዘናጭ B-PRODUCT\n2 I-PRODUCT\nፒስ I-PRODUCT\nከ9 O...
# 7  3 B-PRODUCT\nፒስ I-PRODUCT\n100% I-PRODUCT\nኮተን...
# 8  3 B-PRODUCT\nፒስ I-PRODUCT\n100% I-PRODUCT\nኮተን...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = 'labeled_telegram_product_price_contact.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in df.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")

# %%
def label_message_utf8_with_birr(message):
    tokens = re.findall(r'\S+', message)  # Tokenize while considering non-ASCII characters
    labeled_tokens = []
    
    for token in tokens:
        # Check if token is a price (e.g., 500 ETB, $100, or ብር)
        
        if re.match(r'^\d{10,}$', token):
            labeled_tokens.append(f"{token} O")  # Label as O for "other" or outside of any entity
        elif re.match(r'^\d+(\.\d{1,2})?$', token) or 'ETB' in token or '$' in token or 'ብር' in token:
            labeled_tokens.append(f"{token} I-PRICE")
        
        # Check if token could be a contact number)
        elif any(contact in token for contact in ['0913870090']):
            labeled_tokens.append(f"{token} I-CONTACT")
        
        #elif any(contact in token for contact in ['💥']):
            #labeled_tokens.append(f"{token} B-Product")
        
        # Assume other tokens are part of a product name (this can be refined)
        else:
            labeled_tokens.append(f"{token} O")
    
    return "\n".join(labeled_tokens)

# Apply the updated function to the non-null messages
df['Labeled_Message'] = df['Message'].apply(label_message_utf8_with_birr)
# Out:
# C:\Users\Admin.DESKTOP-M4R2VLU\AppData\Local\Temp\ipykernel_3308\1617971733.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Labeled_Message'] = df['Message'].apply(label_message_utf8_with_birr)
